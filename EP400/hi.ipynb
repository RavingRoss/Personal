# %% [markdown]
# # FOR MASON

# %%
from sympy import *
import matplotlib as plt

# %%
x,a = symbols('x,a')

eq = exp(-x**2)

int = integrate(eq,x)

pprint(int)
plot(int)
# Out:
# √π⋅erf(x)
# ─────────
#     2

# %%
y,n=symbols('y,n')
exp1=((y**3/(3*n**2)-y**4/(4*n**3))**2)/2
exp2=1+(y**3/(3*n**2)-y**4/(4*n**3))
int=(expand(exp1))
pprint(exp2+int)
# Out:
#       3      4       6       7       8
#      y      y       y       y       y
# 1 + ──── - ──── + ───── - ───── + ─────
#        2      3       4       5       6
#     3⋅n    4⋅n    18⋅n    12⋅n    32⋅n
